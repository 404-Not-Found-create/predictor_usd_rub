# %%
# === Imports ===
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt 
from scipy import stats

# %%
# === DataFrame === 
macroeconomic = pd.read_csv(r'MacroEconomic_df.csv')
macroeconomic = macroeconomic[['Inflation', 'Key_rate', 'Brent_price', 'USD_RUB']]
macroeconomic.head()
# Out:
#    Inflation  Key_rate  Brent_price  USD_RUB
# 0       9.52      21.0        69.70   103.27
# 1       8.88      21.0        69.54   100.59
# 2       8.54      21.0        71.56    96.19
# 3       8.63      19.0        69.37    90.92
# 4       9.05      18.0        75.43    88.91

# %%
macroeconomic.info()
macroeconomic.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 112 entries, 0 to 111
# Data columns (total 4 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Inflation    112 non-null    float64
#  1   Key_rate     112 non-null    float64
#  2   Brent_price  112 non-null    float64
#  3   USD_RUB      112 non-null    float64
# dtypes: float64(4)
# memory usage: 3.6 KB
#         Inflation    Key_rate  Brent_price     USD_RUB
# count  112.000000  112.000000   112.000000  112.000000
# mean     6.565536    9.433036    62.708125   71.607411
# std      3.852536    4.147612    18.304466   12.053595
# min      2.200000    4.250000    16.700000   56.440000
# 25%      3.577500    7.250000    48.832500   62.882500
# 50%      5.450000    7.750000    61.940000   67.145000
# 75%      8.322500   11.000000    75.580000   76.147500
# max     17.830000   21.000000   114.340000  111.010000

# %%
sns.heatmap(macroeconomic.corr(), annot=True, cmap='coolwarm')
plt.title('correlation of features')
plt.show()
